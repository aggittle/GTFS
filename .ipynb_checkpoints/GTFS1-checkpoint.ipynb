# %%
#https://nbviewer.jupyter.org/url/nikhilvj.co.in/files/gtfsrt/locations.ipynb

# %%
from google.transit import gtfs_realtime_pb2
from google.protobuf.json_format import MessageToDict, MessageToJson
import urllib3
import requests
import time
import json
import pandas as pd
import datetime
from collections import OrderedDict
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ac99671da7c5> in <module>()
# ----> 1 from google.transit import gtfs_realtime_pb2
#       2 from google.protobuf.json_format import MessageToDict, MessageToJson
#       3 import urllib3
#       4 import requests
#       5 import time
#
# ModuleNotFoundError: No module named 'google'

# %%
stop_ids = pd.read_csv('https://openmobilitydata-data.s3-us-west-1.amazonaws.com/public/feeds/mta/79/20181221/original/stops.txt')

# %% [markdown]
# # FIX: CONVERT stop_name to stop_id

# %%
def get_time(stop, direction):
    #get feed
    http = urllib3.PoolManager()
    feed = gtfs_realtime_pb2.FeedMessage()
    response = requests.get('http://datamine.mta.info/mta_esi.php?key=636e323a9180834b0811457aa7db81ce')
    feed.ParseFromString(response.content)
    dict_obj = MessageToDict(feed)
    collector = []
    #turn stop into stop id
    
    stop_id = stop_ids.loc[(stop_ids['stop_name']==stop), 'stop_id'].tolist()

    
    # turn feed dict object into DataFrame
    for block in dict_obj['entity']:

        row = OrderedDict()
        try:
            row['id'] = block['id']
            row['tripId'] = block['tripUpdate']['trip'].get('tripId','')
            row['routeId'] = block['tripUpdate']['trip'].get('routeId','')
            for i, stop in enumerate(block['tripUpdate']['stopTimeUpdate']):
                minutes = round((int(stop['arrival'].get('time','')) - int(time.time()))/60)
                row[i] = (stop['stopId'], minutes)

            collector.append(row)
        except:
            pass
        
        df = pd.DataFrame(collector)
        
    # print out timetables for given stop_id
    for i, row in df.iterrows():
        for  j in row[3:]:
            if type(j) == tuple:
                if j[0] in stop_id and j[0].endswith(direction):
                    print(row.routeId + ' arriving in ' + str(j[1]) + ' minutes', row.tripId)

# %%
get_time('Atlantic Av - Barclays Ctr', 'N')
# Out:
# 2 arriving in 14 minutes 144100_2..N01X085
# 2 arriving in 1 minutes 142500_2..N01X085
# 4 arriving in 1 minutes 142050_4..N02R
# 4 arriving in 5 minutes 000150_4..N06R

# %%
def get_update(stop, direction):
    http = urllib3.PoolManager()
    feed = gtfs_realtime_pb2.FeedMessage()
    response = requests.get('http://datamine.mta.info/mta_esi.php?key=636e323a9180834b0811457aa7db81ce')
    feed.ParseFromString(response.content)
    dict_obj = MessageToDict(feed)
    collector = []
    
    for block in dict_obj['entity']:
        
        row = OrderedDict()
        try:
            row['id'] = block['id']

            row['trip_id'] = block['vehicle']['trip'].get('tripId','')
            row['route_id'] = block['vehicle']['trip'].get('routeId','')
            row['direction_id'] = block['vehicle']['trip'].get('directionId','')
            row['schedule_relationship'] = block['vehicle'].get('currentStatus','')

    
            row['start_date'] = block['vehicle']['trip'].get('startDate','')
            row['current_stop_sequence'] = block['vehicle'].get('currentStopSequence','')
            row['current_status'] = block['vehicle'].get('currentStatus','')
            row['timestamp'] = block['vehicle'].get('timestamp','')
            row['stop_id'] = block['vehicle'].get('stopId','')
            collector.append(row)
        except:
            pass

    df = pd.DataFrame(collector)
    
    feedtime = int(dict_obj['header']['timestamp'])
    #print('Feed timestamp:',feedtime,',', datetime.datetime.fromtimestamp(feedtime))
    df['feed time'] = datetime.datetime.fromtimestamp(feedtime)
    
    df = pd.merge(df, stop_ids[['stop_id', 'stop_name']],  on='stop_id', how='outer')
    
    stop_id = [x for x in df.loc[(df['stop_name'] == stop),'stop_id'].tolist() if x[-1] == direction][0][:-1]
    
    stops = []
    if direction == 'N':
        stops.extend(range(int(stop_id), int(stop_id)+10))
    elif direction == 'S':
        stops.extend(range(int(stop_id)-10 ,int(stop_id)))
       
    stops = [str(x)+direction for x in stops]
    
    print(df[((df.stop_id == stops[0]) |
   (df.stop_id == stops[1]) |
   (df.stop_id == stops[2])  |
   (df.stop_id == stops[3]) |
   (df.stop_id == stops[4]) |
   (df.stop_id == stops[5]) |
   (df.stop_id == stops[6]))][['current_status','route_id','stop_name', 'stop_id', 'trip_id']])
    
    return df

# %%
[x for x in df.loc[(df['stop_name'] == 'Atlantic Av - Barclays Ctr'),'stop_id'].tolist() if x[-1] == 'S']
# Out:
# []

# %%
df = get_update('Atlantic Av - Barclays Ctr', 'S')
# Out:
#     current_status route_id                    stop_name stop_id  \
# 21      STOPPED_AT        2                      Wall St    230S
# 25      STOPPED_AT        2  Central Park North (110 St)    227S
# 220            NaN      NaN                       125 St    225S
# 222            NaN      NaN                       116 St    226S
# 226            NaN      NaN                      Park Pl    228S
# 229            NaN      NaN                    Fulton St    229S
# 233            NaN      NaN                     Clark St    231S
#
#                trip_id
# 21   138000_2..S01X004
# 25   140650_2..S01X086
# 220                NaN
# 222                NaN
# 226                NaN
# 229                NaN
# 233                NaN

# %%
df
# Out:
#         id            trip_id route_id direction_id schedule_relationship  \
# 0   000002  131900_1..N03X024        1                      IN_TRANSIT_TO
# 1   000004  132400_1..N03X024        1                      IN_TRANSIT_TO
# 2   000006     132450_1..S03R        1                         STOPPED_AT
# 3   000008  132900_1..N03X024        1                         STOPPED_AT
# 4   000010  133400_1..N03X024        1                      IN_TRANSIT_TO
# 5   000012     133450_1..S03R        1                      IN_TRANSIT_TO
# 6   000014  134000_1..N03X024        1                      IN_TRANSIT_TO
# 7   000016     134450_1..S03R        1                         STOPPED_AT
# 8   000019  134900_1..N03X024        1                      IN_TRANSIT_TO
# 9   000021     135450_1..S03R        1                         STOPPED_AT
# 10  000023  135800_1..N03X024        1                         STOPPED_AT
# 11  000026     136450_1..S03R        1                      IN_TRANSIT_TO
# 12  000028  136750_1..N03X024        1                         STOPPED_AT
# 13  000030     137450_1..S03R        1                         STOPPED_AT
# 14  000032  137900_1..N03X024        1                         STOPPED_AT
# 15  000040     128000_2..N01R        2                      IN_TRANSIT_TO
# 16  000042     128800_2..N01R        2                      IN_TRANSIT_TO
# 17  000044  129300_2..S01X004        2                        INCOMING_AT
# 18  000046     129600_2..N01R        2                        INCOMING_AT
# 19  000048     130400_2..N01R        2                         STOPPED_AT
# 20  000050  130600_2..S01X004        2                      IN_TRANSIT_TO
# 21  000052     131500_2..N01R        2                      IN_TRANSIT_TO
# 22  000054  131900_2..S01X004        2                         STOPPED_AT
# 23  000056     132400_2..N01R        2                         STOPPED_AT
# 24  000058  133100_2..S01X004        2                      IN_TRANSIT_TO
# 25  000060     133400_2..N01R        2                      IN_TRANSIT_TO
# 26  000086     132500_3..N01R        3                         STOPPED_AT
# 27  000062  134350_2..S01X004        2                         STOPPED_AT
# 28  000064     134400_2..N01R        2                      IN_TRANSIT_TO
# 29  000066     135500_2..N01R        2                         STOPPED_AT
# ..     ...                ...      ...          ...                   ...
# 57  000132  133700_4..S06X117        4                      IN_TRANSIT_TO
# 58  000136  134700_4..S06X117        4                      IN_TRANSIT_TO
# 59  000134  134000_4..S05X004        4                      IN_TRANSIT_TO
# 60  000138  135000_4..S05X004        4                         STOPPED_AT
# 61  000140        137050_4..S        4                      IN_TRANSIT_TO
# 62  000143  137750_4..S01X013        4                      IN_TRANSIT_TO
# 63  000145     131400_5..N73R        5                      IN_TRANSIT_TO
# 64  000147     132100_5..S08R        5                         STOPPED_AT
# 65  000149     132400_5..N73R        5                         STOPPED_AT
# 66  000157     136400_5..N73R        5                      IN_TRANSIT_TO
# 67  000188     136000_6..N01R        6                         STOPPED_AT
# 68  000159     137550_5..N73R        5                      IN_TRANSIT_TO
# 69  000164     130100_6..N01R        6                         STOPPED_AT
# 70  000166     130600_6..N01R        6                      IN_TRANSIT_TO
# 71  000168     131150_6..N01R        6                         STOPPED_AT
# 72  000170     132350_6..N01R        6                         STOPPED_AT
# 73  000172     132550_6..S01R        6                      IN_TRANSIT_TO
# 74  000174     133050_6..N01R        6                         STOPPED_AT
# 75  000178     133750_6..N01R        6                      IN_TRANSIT_TO
# 76  000205     133400_6..N01R        6                      IN_TRANSIT_TO
# 77  000176     133350_6..S01R        6                      IN_TRANSIT_TO
# 78  000180     134150_6..S01R        6                         STOPPED_AT
# 79  000182     134450_6..N01R        6                         STOPPED_AT
# 80  000184     134850_6..S01R        6                         STOPPED_AT
# 81  000186     135200_6..N01R        6                         STOPPED_AT
# 82  000190     136050_6..S01R        6                         STOPPED_AT
# 83  000192     136800_6..N01R        6                         STOPPED_AT
# 84  000194     137250_6..S01R        6                         STOPPED_AT
# 85  000196     137600_6..N01R        6                         STOPPED_AT
# 86  000207     138000_GS.N01R       GS                      IN_TRANSIT_TO
#
#    start_date  current_stop_sequence current_status   timestamp stop_id  \
# 0    20190404                     33  IN_TRANSIT_TO  1554433248    101N
# 1    20190404                     31  IN_TRANSIT_TO  1554433249    104N
# 2    20190404                     38     STOPPED_AT  1554433247    142S
# 3    20190404                     29     STOPPED_AT  1554433249    107N
# 4    20190404                     26  IN_TRANSIT_TO  1554433251    110N
# 5    20190404                     33  IN_TRANSIT_TO  1554433246    135S
# 6    20190404                     24  IN_TRANSIT_TO  1554433251    112N
# 7    20190404                     23     STOPPED_AT  1554433242    125S
# 8    20190404                     22  IN_TRANSIT_TO  1554433247    114N
# 9    20190404                     19     STOPPED_AT  1554433224    121S
# 10   20190404                     17     STOPPED_AT  1554433225    124N
# 11   20190404                     12  IN_TRANSIT_TO  1554433247    114S
# 12   20190404                     11     STOPPED_AT  1554433221    130N
# 13   20190404                      5     STOPPED_AT  1554433238    107S
# 14   20190404                      2     STOPPED_AT  1554433206    139N
# 15   20190404                     49  IN_TRANSIT_TO  1554433119    201N
# 16   20190404                     47  IN_TRANSIT_TO  1554433239    205N
# 17   20190404                     42    INCOMING_AT  1554433243    243S
# 18   20190404                     37    INCOMING_AT  1554433249    215N
# 19   20190404                     35     STOPPED_AT  1554433205    217N
# 20   20190404                     35  IN_TRANSIT_TO  1554433247    232S
# 21   20190404                     31  IN_TRANSIT_TO  1554433248    221N
# 22   20190404                     30     STOPPED_AT  1554433203    137S
# 23   20190404                     27     STOPPED_AT  1554433238    226N
# 24   20190404                     27  IN_TRANSIT_TO  1554433230    127S
# 25   20190404                     25  IN_TRANSIT_TO  1554433251    120N
# 26   20190404                     28     STOPPED_AT  1554433194    120N
# 27   20190404                     22     STOPPED_AT  1554433222    225S
# 28   20190404                     21  IN_TRANSIT_TO  1554433252    132N
# 29   20190404                     15     STOPPED_AT  1554433245    232N
# ..        ...                    ...            ...         ...     ...
# 57   20190404                     14  IN_TRANSIT_TO  1554433242    640S
# 58   20190404                     14  IN_TRANSIT_TO  1554433252    640S
# 59   20190404                     24  IN_TRANSIT_TO  1554433240    423S
# 60   20190404                      9     STOPPED_AT  1554433203    419S
# 61   20190404                      5  IN_TRANSIT_TO  1554433252    629S
# 62   20190404                      3  IN_TRANSIT_TO  1554433244    415S
# 63   20190404                     24  IN_TRANSIT_TO  1554433243    502N
# 64   20190404                     23     STOPPED_AT  1554433226    418S
# 65   20190404                     20     STOPPED_AT  1554433191    213N
# 66   20190404                      8  IN_TRANSIT_TO  1554433239    626N
# 67   20190404                     15     STOPPED_AT  1554433246    626N
# 68   20190404                      5  IN_TRANSIT_TO  1554433243    635N
# 69   20190404                     38     STOPPED_AT  1554433240    601N
# 70   20190404                     36  IN_TRANSIT_TO  1554433243    603N
# 71   20190404                     27     STOPPED_AT  1554433230    613N
# 72   20190404                     23     STOPPED_AT  1554433227    617N
# 73   20190404                     33  IN_TRANSIT_TO  1554433242    635S
# 74   20190404                     21     STOPPED_AT  1554433233    619N
# 75   20190404                     21  IN_TRANSIT_TO  1554433248    619N
# 76   20190404                     21  IN_TRANSIT_TO  1554433236    619N
# 77   20190404                     29  IN_TRANSIT_TO  1554433250    631S
# 78   20190404                     24     STOPPED_AT  1554433246    626S
# 79   20190404                     19     STOPPED_AT  1554433202    622N
# 80   20190404                     20     STOPPED_AT  1554433211    622S
# 81   20190404                     17     STOPPED_AT  1554433223    624N
# 82   20190404                     14     STOPPED_AT  1554433225    615S
# 83   20190404                      7     STOPPED_AT  1554433235    634N
# 84   20190404                      7     STOPPED_AT  1554433232    608S
# 85   20190404                      5     STOPPED_AT  1554433242    636N
# 86   20190404                      2  IN_TRANSIT_TO  1554433242    902N
#
#              feed time                    stop_name
# 0  2019-04-04 23:00:53  Van Cortlandt Park - 242 St
# 1  2019-04-04 23:00:53                       231 St
# 2  2019-04-04 23:00:53                  South Ferry
# 3  2019-04-04 23:00:53                       215 St
# 4  2019-04-04 23:00:53                       191 St
# 5  2019-04-04 23:00:53                     Canal St
# 6  2019-04-04 23:00:53      168 St - Washington Hts
# 7  2019-04-04 23:00:53      59 St - Columbus Circle
# 8  2019-04-04 23:00:53                       145 St
# 9  2019-04-04 23:00:53                        86 St
# 10 2019-04-04 23:00:53       66 St - Lincoln Center
# 11 2019-04-04 23:00:53                       145 St
# 12 2019-04-04 23:00:53                        23 St
# 13 2019-04-04 23:00:53                       215 St
# 14 2019-04-04 23:00:53                    Rector St
# 15 2019-04-04 23:00:53           Wakefield - 241 St
# 16 2019-04-04 23:00:53                       233 St
# 17 2019-04-04 23:00:53                  Winthrop St
# 18 2019-04-04 23:00:53                       174 St
# 19 2019-04-04 23:00:53                   Simpson St
# 20 2019-04-04 23:00:53                 Borough Hall
# 21 2019-04-04 23:00:53                3 Av - 149 St
# 22 2019-04-04 23:00:53                  Chambers St
# 23 2019-04-04 23:00:53                       116 St
# 24 2019-04-04 23:00:53             Times Sq - 42 St
# 25 2019-04-04 23:00:53                        96 St
# 26 2019-04-04 23:00:53                        96 St
# 27 2019-04-04 23:00:53                       125 St
# 28 2019-04-04 23:00:53                        14 St
# 29 2019-04-04 23:00:53                 Borough Hall
# ..                 ...                          ...
# 57 2019-04-04 23:00:53  Brooklyn Bridge - City Hall
# 58 2019-04-04 23:00:53  Brooklyn Bridge - City Hall
# 59 2019-04-04 23:00:53                 Borough Hall
# 60 2019-04-04 23:00:53                      Wall St
# 61 2019-04-04 23:00:53                        59 St
# 62 2019-04-04 23:00:53     149 St - Grand Concourse
# 63 2019-04-04 23:00:53                Baychester Av
# 64 2019-04-04 23:00:53                    Fulton St
# 65 2019-04-04 23:00:53                     E 180 St
# 66 2019-04-04 23:00:53                        86 St
# 67 2019-04-04 23:00:53                        86 St
# 68 2019-04-04 23:00:53             14 St - Union Sq
# 69 2019-04-04 23:00:53              Pelham Bay Park
# 70 2019-04-04 23:00:53                Middletown Rd
# 71 2019-04-04 23:00:53               Hunts Point Av
# 72 2019-04-04 23:00:53                   Cypress Av
# 73 2019-04-04 23:00:53             14 St - Union Sq
# 74 2019-04-04 23:00:53                3 Av - 138 St
# 75 2019-04-04 23:00:53                3 Av - 138 St
# 76 2019-04-04 23:00:53                3 Av - 138 St
# 77 2019-04-04 23:00:53        Grand Central - 42 St
# 78 2019-04-04 23:00:53                        86 St
# 79 2019-04-04 23:00:53                       116 St
# 80 2019-04-04 23:00:53                       116 St
# 81 2019-04-04 23:00:53                       103 St
# 82 2019-04-04 23:00:53                     E 149 St
# 83 2019-04-04 23:00:53                        23 St
# 84 2019-04-04 23:00:53                  Parkchester
# 85 2019-04-04 23:00:53                     Astor Pl
# 86 2019-04-04 23:00:53             Times Sq - 42 St
#
# [87 rows x 12 columns]

# %%
[x for x in df.loc[(df['stop_name'] == '14 St'),'stop_id'].tolist()]
# Out:
# ['132S', '132S', '132N']

# %%
df.loc[(df['stop_name'] == '14 St'),'stop_id'].tolist()
# Out:
# ['132N', '132S']

# %%
while True:
    try:
        get_time('234N')
        print('\n')
    except:
        continue
    time.sleep(10)
# Out:
# 2 arriving in 9 minutes
# 3 arriving in 5 minutes
# 3 arriving in 14 minutes
# 4 arriving in 4 minutes
#
#
# 2 arriving in 9 minutes
# 3 arriving in 5 minutes
# 3 arriving in 14 minutes
# 3 arriving in 26 minutes
# 4 arriving in 3 minutes
#
#
# 2 arriving in 9 minutes
# 3 arriving in 5 minutes
# 3 arriving in 14 minutes
# 3 arriving in 26 minutes
# 4 arriving in 3 minutes
#
#
# 2 arriving in 9 minutes
# 3 arriving in 4 minutes
# 3 arriving in 14 minutes
# 3 arriving in 25 minutes
# 4 arriving in 3 minutes
#
#
# 2 arriving in 9 minutes
# 3 arriving in 4 minutes
# 3 arriving in 14 minutes
# 3 arriving in 25 minutes
# 4 arriving in 3 minutes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9450ecc06bbe> in <module>
#       5     except:
#       6         continue
# ----> 7     time.sleep(10)
#
# KeyboardInterrupt:

# %%
stop_ids.groupby('stop_name')['stop_id'].nunique()['Atlantic Av - Barclays Ctr']
# Out:
# 9
